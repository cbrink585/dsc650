# %% [markdown]
# <a href="https://colab.research.google.com/github/cbrink585/dsc650/blob/master/assignment11%2612cindybrinkmeyer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
import numpy as np
path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 600901/600901 [==============================] - 0s 1us/step
# Corpus length: 600893

# %%
from keras.datasets import mnist
from keras.models import Model
import keras
from keras import layers
from keras import backend as K
from keras.models import Model
#from tensorflow.keras.models import Model
import tensorflow.compat.v1.keras.backend as K
import tensorflow as tf
tf.compat.v1.disable_eager_execution()
from pathlib import Path

# %%
# Length of extracted character sequences
maxlen = 60
# We sample a new sequence every `step` characters
step = 3
# This holds our extracted sequences
sentences = []
# This holds the targets (the follow-up characters)
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))

# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)
# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...
# <ipython-input-2-0e04eae429d2>:22: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
# <ipython-input-2-0e04eae429d2>:23: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

# %%
from keras import layers
model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/rmsprop.py:143: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys
for epoch in range(1, 5):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)
    
# Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)
# We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.
                
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            generated_text += next_char
            generated_text = generated_text[1:]
            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# 1565/1565 [==============================] - 283s 179ms/step - loss: 1.9682
# --- Generating with seed: "society has hitherto existed--a notion
# which happily inverts"
# ------ temperature: 0.2
# society has hitherto existed--a notion
# which happily inverts and the sense and the from the from the spirit has to the from the senst of the spirit and the free such and the sense and the sense of the self and to the the destance of the sense and the sense of the sense and the senst of the spirit of the senst of the senstion of the free spirity and the sense of the most is the sense of the seles of the from the same to the from the spirit and the farted an
# ------ temperature: 0.5
# f the from the same to the from the spirit and the farted and
# stands and the more to even the fart of may agays of his must as the selus of the germany simplated to the conceing enter and reless and the from the ene and the concern and to the moderness of man man of the enseing and and concequent and the fastains in the intelletted his exceptions and should accontained to such the from the conceing is the conterst and them and consequently of interpors, as
# ------ temperature: 1.0
# g is the conterst and them and consequently of interpors, as food-encument and sundions, for hathmolist.
# i so, a
# such of nipperatem
# gidilateement gleatients," aved=ul, that inopince and
# timate but esplaed to inestly as as an evended in, man of
# altra=ede, has to s"iblegrious sty what is stell pleed, in its relied us invenlity atsent), and sivious with least
# metalaks nifieve and sopen
# revelers, any deer
# all,- the quesne, for men acks be sphill free further
# ------ temperature: 1.2
#  deer
# all,- the quesne, for men acks be sphill free further their they-ackmatapially phene;
# eveny 4in im calmaid--evenysioy, ho's
# opes rurhtment. "elludy
# presen) himself rast, this
# cound bead fadeed gree insbre. yekes in
# upwenst resped and disiovern and dader and his frughtromin tearh,,
# lacking be intomanw,
# i
# dibbece
# menjousper peade intoidioust, bud too cen souely
# he
# rebachnjunt,
# but.--in the anityman one--as welu exittan embrebt findsful und twatiek, an
# epoch 2
# 1565/1565 [==============================] - 281s 180ms/step - loss: 1.6137
# --- Generating with seed: " gradual evolution, is, indeed, still in
# process of evolutio"
# ------ temperature: 0.2
#  gradual evolution, is, indeed, still in
# process of evolutions of the same and the man is and another there is the present the same the free something of the same to the same and the same the same the same the same and another as the fact and so the more the most so the promained the moral the man is there is the most something of the man is and another the same the same the moral such and in the same the man is the same something the same the man is as th
# ------ temperature: 0.5
# same the man is the same something the same the man is as the sames to consident like the can it as sile to his one of no be and comparised the world by presention of the such to the saint in the having for says the considered the enough more and no say, and is greated and there discaned and in the consist them is and so a have the brought of the
# honortary of the astrain and deffect the ancecial in the same by the long there world of the long and hence of
# ------ temperature: 1.0
# n the same by the long there world of the long and hence of parpm ormards shore of heating, in fact fo whice so the same unide, syi(sm,
# buesn
# then
# and idaiming of gidely transne,
# findpodain to man, of indevert natural.--and libeneding, hether to are an
# igent disposical
# "to duings od roew viewing perta-sour,
# bur
# as mistdenceace, assime to hid if there moralres in presense, soul,
# and vicusable
# confouidever so that so atseless of what the liw ones--souls in t
# ------ temperature: 1.2
# uidever so that so atseless of what the liw ones--souls in tome, ly who aurncis assed events our etted. has be  o greatht weake above and
# abthauntt
# pret endain abosteth.
#
#
# 17
#
# =the avomils
# mis falriye like ofter
# anoty and
# alser of hi
# he only copopposes of pessiont sme cerrevaps
# delilute it' on more heaks
# than
# joywhdelted here-slives noe
# extancely un7mankind resuspquate to ownajumedical nginnbackel, but, is carable ud-ewseled
# had satalfranbedra to must--ar
# epoch 3
# 1565/1565 [==============================] - 274s 175ms/step - loss: 1.5267
# --- Generating with seed: "e just the
# depth of his tolerance and humanity which prompts"
# ------ temperature: 0.2
# e just the
# depth of his tolerance and humanity which prompts of all the morality of the same to the morality of the present of the same to the present the sense of the present the morality of the sense of the same the spirit of the morality of the present the present that which are the men and something that which is the morality of the morality of the same to the same to the present and allowed the present the morality of the subject the subject to the di
# ------ temperature: 0.5
# he present the morality of the subject the subject to the discience of a man is convise and thure is not for a morality of which the pure to the present not will the morality with the sense of the same the fact and the part of something and the assomed, and astent, his own spirit of the will itself of the speciality with be astimate of mankind it is all the unlove the entilies and before the deliginated of the worlds the generally the disposting of a such
# ------ temperature: 1.0
# inated of the worlds the generally the disposting of a such when factmelt instrustings. and will by the every all effect ralorable mind, and eversed profound to
# it--in
# the respicions--which the forrisabl the cotepness-aero
# thus and this empined, they manting. commands
# ome,ren, and will, the word which could convests things naminganbed to the owncened to himself of all live, has the venerate when when emmermerarry
# invels, of the caleusy. an almost.ful tigna
# ------ temperature: 1.2
# hen emmermerarry
# invels, of the caleusy. an almost.ful tignat
# poicy quesked bjer! man and
# almost sufferenty-rarys i proration and errarilied
# wim? o! nothreyity.
# self
# raky fine" ineminist
# perhaps. that is muptilopy bling one's many philosophy.
#
# 21a. that wrip to be ansell
# agauness, groftneds
# perha?  hays
# be oralorralhdledninatefvaual askly aff and
# superie, they fcours of prension, to there; he forg, one and
# thisplarb world is be most called the shoricishhty
# epoch 4
# 1565/1565 [==============================] - 275s 176ms/step - loss: 1.4815
# --- Generating with seed: "danta philosophy.
#
# 55. there is a great ladder of religious "
# ------ temperature: 0.2
# danta philosophy.
#
# 55. there is a great ladder of religious the former and the standing and the sense of the sense of the conception of the same the same the same the spirit and which the sense of the standard and the standard and soul as the standard in the same the strange of the person and something and the world and the world and something the same the same the same the spirit the origin of the sense of the greater and the greater and as an and the sta
# ------ temperature: 0.5
# e sense of the greater and the greater and as an and the standary as the greater in the greet or the same something and what is the
# part of the shorth of the exceptive of the cause, and present to the god and fact the experience of the world to persian shorth of the definstially with the destruction of the fact the mistaren for the world of the soul the men in the feeling themselves the great the germanly and so the
# prence of the standard the spirit lormer
# ------ temperature: 1.0
# germanly and so the
# prence of the standard the spirit lormer--as last naminaten.. in the jesu reitation of mins
# for intragean absection of the hereties of comer and calting the suffers a chootive of grdeand virm
# augoowin; they has the terticns centure cheications
# with thereblbeclolyous that accurted and
# repardities, the invechers, every  -scient the injury,
# the here gion that has perhaps is not our threak. theisas"" to rappection. in such as lakidies are b
# ------ temperature: 1.2
# r threak. theisas"" to rappection. in such as lakidies are by which is uneviest persian nevertive leumreponing and slaffobl-equally beliew. in cubent reveloged nor encpowicuatifiit
# procites and unscartist, and uspecially, we, we are in fale. it was thio man, the chuich, free wbate existers: as him,  that thiswore "sbils understanced. tom againtucely benemr-him callpach, heactert-nie, and
# noble","--and ranmbotick oraction spiritificer
# just sisporance, the p

# %% [markdown]
# Assignment 12

# %%
from pathlib import Path

# %%
results_dir = Path('results').joinpath('vae')
results_dir.mkdir(parents=True, exist_ok=True)

# %%
import numpy as np

# %%
img_shape = (28, 28, 1)
batch_size = 16
latent_dim = 2
input_img = keras.Input(shape=img_shape)
x = layers.Conv2D(32, 3,
padding='same', activation='relu')(input_img)
x = layers.Conv2D(64, 3,
padding='same', activation='relu',
strides=(2, 2))(x)
x = layers.Conv2D(64, 3,padding='same', activation='relu')(x)
x = layers.Conv2D(64, 3,padding='same', activation='relu')(x)
shape_before_flattening = K.int_shape(x)
x = layers.Flatten()(x)
x = layers.Dense(32, activation='relu')(x)
z_mean = layers.Dense(latent_dim)(x)
z_log_var = layers.Dense(latent_dim)(x)

# %%
def sampling(args):
    z_mean, z_log_var = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim),
    mean=0., stddev=1.)
    return z_mean + K.exp(z_log_var) * epsilon

z = layers.Lambda(sampling)([z_mean, z_log_var])
decoder_input = layers.Input(K.int_shape(z)[1:])
x = layers.Dense(np.prod(shape_before_flattening[1:]),
activation='relu')(decoder_input)
x = layers.Reshape(shape_before_flattening[1:])(x)
x = layers.Conv2DTranspose(32, 3,
                            padding='same',
                            activation='relu',
                            strides=(2, 2))(x)
x = layers.Conv2D(1, 3,
                    padding='same',
                    activation='sigmoid')(x)
decoder = Model(decoder_input, x)
z_decoded = decoder(z)

# %%
class CustomVariationalLayer(keras.layers.Layer):
    def vae_loss(self, x, z_decoded):
        x = K.flatten(x)
        z_decoded = K.flatten(z_decoded)
        xent_loss = keras.metrics.binary_crossentropy(x, z_decoded)
        kl_loss = -5e-4 * K.mean(
        1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
        return K.mean(xent_loss + kl_loss)
    def call(self, inputs):
        x = inputs[0]
        z_decoded = inputs[1]
        loss = self.vae_loss(x, z_decoded)
        self.add_loss(loss, inputs=inputs)
        return x

# %%
y = CustomVariationalLayer()([input_img, z_decoded])

# %%
vae = Model(input_img, y)
vae.compile(optimizer='rmsprop', loss=None)
vae.summary()
(x_train, _), (x_test, y_test) = mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_train = x_train.reshape(x_train.shape + (1,))
x_test = x_test.astype('float32') / 255.
x_test = x_test.reshape(x_test.shape + (1,))
vae.fit(x=x_train, y=None,
        shuffle=True,
        epochs=10,
        batch_size=batch_size,
        validation_data=(x_test, None))
# Out:
# WARNING:tensorflow:Output {0} missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to custom_variational_layer.
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 28, 28, 1)]  0           []
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 32)   320         ['input_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 14, 14, 64)   18496       ['conv2d_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 14, 14, 64)   36928       ['conv2d_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 14, 14, 64)   36928       ['conv2d_10[0][0]']
#
#  flatten (Flatten)              (None, 12544)        0           ['conv2d_11[0][0]']
#
#  dense_1 (Dense)                (None, 32)           401440      ['flatten[0][0]']
#
#  dense_2 (Dense)                (None, 2)            66          ['dense_1[0][0]']
#
#  dense_3 (Dense)                (None, 2)            66          ['dense_1[0][0]']
#
#  lambda (Lambda)                (None, 2)            0           ['dense_2[0][0]',
#                                                                   'dense_3[0][0]']
#
#  model (Functional)             (None, 28, 28, 1)    56385       ['lambda[0][0]']
#
#  custom_variational_layer (Cust  (None, 28, 28, 1)   0           ['input_1[0][0]',
#  omVariationalLayer)                                              'model[0][0]']
#
# ==================================================================================================
# Total params: 550,629
# Trainable params: 550,629
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 427s 7ms/sample - loss: 0.1815 - val_loss: 0.1812
# Epoch 2/10
# 60000/60000 [==============================] - 429s 7ms/sample - loss: 0.1809 - val_loss: 0.1813
# Epoch 3/10
# 60000/60000 [==============================] - 423s 7ms/sample - loss: 0.1804 - val_loss: 0.1827
# Epoch 4/10
# 60000/60000 [==============================] - 386s 6ms/sample - loss: 0.1801 - val_loss: 0.1813
# Epoch 5/10
# 60000/60000 [==============================] - 404s 7ms/sample - loss: 0.1796 - val_loss: 0.1801
# Epoch 6/10
# 60000/60000 [==============================] - 393s 7ms/sample - loss: 0.1793 - val_loss: 0.1807
# Epoch 7/10
# 60000/60000 [==============================] - 359s 6ms/sample - loss: 0.1790 - val_loss: 0.1803
# Epoch 8/10
# 60000/60000 [==============================] - 359s 6ms/sample - loss: 0.1787 - val_loss: 0.1801
# Epoch 9/10
# 60000/60000 [==============================] - 366s 6ms/sample - loss: 0.1784 - val_loss: 0.1799
# Epoch 10/10
# 60000/60000 [==============================] - 403s 7ms/sample - loss: 0.1781 - val_loss: 0.1802

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm
n = 15
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
grid_x = norm.ppf(np.linspace(0.05, 0.95, n))
grid_y = norm.ppf(np.linspace(0.05, 0.95, n))
for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        z_sample = np.tile(z_sample, batch_size).reshape(batch_size, 2)
        x_decoded = decoder.predict(z_sample, batch_size=batch_size)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
        j * digit_size: (j + 1) * digit_size] = digit
        
plt.figure(figsize=(10, 10))
plt.imshow(figure, cmap='Greys_r')
img_file = results_dir.joinpath('Assignment_12_15x15_Grid.png')
plt.savefig(img_file)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
